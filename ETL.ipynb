# %%
"""ETL from CSV to SQlite database"""
import csv
import sqlite3
from datetime import datetime
import logging


def parse_day(text):
    return datetime.strptime(text, '%Y%m%d')


def parse_temp(text):
    celsius = float(text) * 10
    return (celsius * 9/5) + 32


converts = [
    ('DATE', 'day', parse_day),
    ('TMIN', 'min_temp', parse_temp),
    ('TMAX', 'max_temp', parse_temp),
    ('SNOW', 'snow', int),
]


def row2db(row):
    obj = {}
    for src, dest, conv in converts:
        try:
            obj[dest] = conv(row[src])
        except ValueError:
            return None
    return obj


def iter_records(csv_file):
    with open(csv_file) as fp:
        for lnum, row in enumerate(csv.DictReader(fp), 2):
            obj = row2db(row)
            if not obj:
                logging.warning('%s:%d skipping bad row', csv_file, lnum)
                continue
            yield obj


schema_sql = '''
CREATE TABLE IF NOT EXISTS weather (
    day DATE,	    -- day of measurements
    min_temp FLOAT, -- min temperature in Fahrenheit
    max_temp FLOAT, -- max temperature in Fahrenheit
    snow INTEGETR   -- snow in inches
);

CREATE INDEX IF NOT EXISTS weather_day ON weather(day);
'''


insert_sql = '''
INSERT INTO weather (
    day,
    min_temp,
    max_temp,
    snow
) VALUES (
    :day,
    :min_temp,
    :max_temp,
    :snow
)
'''


def etl(csv_file, db_file):
    with sqlite3.connect(db_file) as db:
        cur = db.cursor()
        cur.executescript(schema_sql)
        cur.executemany(insert_sql, iter_records(csv_file))
        return cur.rowcount


if __name__ == '__main__':
    count = etl('/content/weather.csv', '/content/weather.db')
    print(f'inserted {count} records')
# Out:
# WARNING:root:/content/weather.csv:126 skipping bad row
# WARNING:root:/content/weather.csv:168 skipping bad row
# WARNING:root:/content/weather.csv:184 skipping bad row
# WARNING:root:/content/weather.csv:395 skipping bad row
# WARNING:root:/content/weather.csv:761 skipping bad row
# WARNING:root:/content/weather.csv:915 skipping bad row
# WARNING:root:/content/weather.csv:943 skipping bad row
# WARNING:root:/content/weather.csv:978 skipping bad row
# WARNING:root:/content/weather.csv:1042 skipping bad row
# WARNING:root:/content/weather.csv:1098 skipping bad row
# WARNING:root:/content/weather.csv:1105 skipping bad row
# WARNING:root:/content/weather.csv:1236 skipping bad row
# WARNING:root:/content/weather.csv:1245 skipping bad row
# WARNING:root:/content/weather.csv:1246 skipping bad row
# WARNING:root:/content/weather.csv:1357 skipping bad row
# WARNING:root:/content/weather.csv:1498 skipping bad row
# WARNING:root:/content/weather.csv:1585 skipping bad row
# WARNING:root:/content/weather.csv:1625 skipping bad row
# WARNING:root:/content/weather.csv:1851 skipping bad row
# WARNING:root:/content/weather.csv:2187 skipping bad row
# WARNING:root:/content/weather.csv:2215 skipping bad row
# WARNING:root:/content/weather.csv:2343 skipping bad row
# WARNING:root:/content/weather.csv:2385 skipping bad row
# WARNING:root:/content/weather.csv:2400 skipping bad row
# WARNING:root:/content/weather.csv:2461 skipping bad row
# WARNING:root:/content/weather.csv:2693 skipping bad row
# WARNING:root:/content/weather.csv:2739 skipping bad row
# WARNING:root:/content/weather.csv:2801 skipping bad row
# WARNING:root:/content/weather.csv:2868 skipping bad row
# WARNING:root:/content/weather.csv:3031 skipping bad row
# WARNING:root:/content/weather.csv:3185 skipping bad row
# WARNING:root:/content/weather.csv:3319 skipping bad row
# WARNING:root:/content/weather.csv:3365 skipping bad row
# WARNING:root:/content/weather.csv:3400 skipping bad row
# WARNING:root:/content/weather.csv:3433 skipping bad row
# WARNING:root:/content/weather.csv:3567 skipping bad row
# WARNING:root:/content/weather.csv:3572 skipping bad row
# WARNING:root:/content/weather.csv:3663 skipping bad row
# WARNING:root:/content/weather.csv:4087 skipping bad row
# WARNING:root:/content/weather.csv:4088 skipping bad row
# WARNING:root:/content/weather.csv:4150 skipping bad row
# WARNING:root:/content/weather.csv:4256 skipping bad row
# WARNING:root:/content/weather.csv:4360 skipping bad row
# WARNING:root:/content/weather.csv:4486 skipping bad row
# WARNING:root:/content/weather.csv:4626 skipping bad row
# WARNING:root:/content/weather.csv:4668 skipping bad row
# WARNING:root:/content/weather.csv:4718 skipping bad row
# WARNING:root:/content/weather.csv:4736 skipping bad row
# WARNING:root:/content/weather.csv:4758 skipping bad row
# WARNING:root:/content/weather.csv:4810 skipping bad row
# WARNING:root:/content/weather.csv:5009 skipping bad row
# WARNING:root:/content/weather.csv:5203 skipping bad row
# inserted 5169 records
